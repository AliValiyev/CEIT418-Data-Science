# %% [markdown]
# # Module 4 Lab Assignment

# %% [markdown]
# This assignment contains 12 tasks, with varying points depending on the difficulty level. When working on the tasks you MUST use the concepts covered in Module 4 Lecture. Solutions with loops and list comprehensions are NOT accepted.
#
# If you have any questions please post them on Slack timely. Help-seeking (and giving) is highly encouraged in this course.

# %% [markdown]
# Please starting to work on the tasks, please import `numpy` and pandas libraries.

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %% [markdown]
# ## Generating Dataset
#
# Our dataset will be page view dataset where column represents the days (DAY 1 to DAY 5), and the row represents the students who visits the pages.
#
# #### TASK 1 [+4].
# Generate a random array (*named* `data`) with values ranging between 0-1000. The array should have 10 rows and 5 columns.
#
# **Use the seed of 10** so that it will always generate the same set of random numbers.

# %%
np.random.seed(10) # seed for reproducibility
data = np.random. randint(1000, size=(10, 5)) # Two-dimensional array
data
# Out:
# array([[265, 125, 996, 527, 320],
#        [369, 123, 156, 985, 733],
#        [496, 925, 881,   8,  73],
#        [256, 490,  40, 502, 420],
#        [371, 528, 356, 239, 395],
#        [ 54, 344, 363, 122, 574],
#        [545, 200, 868, 974, 689],
#        [691,  54,  77, 453,  13],
#        [755, 409, 382, 653, 860],
#        [342, 798, 670,  89, 652]])

# %% [markdown]
# Create a list (or array), named `students`, that contain the following values in the exact order:
# `'C', 'H','A', 'D', 'E', 'J', 'G', 'I', 'B', 'F'`

# %%
students = np.array(['C', 'H','A', 'D', 'E', 'J', 'G', 'I', 'B', 'F'])
students
# Out:
# array(['C', 'H', 'A', 'D', 'E', 'J', 'G', 'I', 'B', 'F'], dtype='<U1')

# %% [markdown]
# Create a new dataframe, which has the `data` as the data source, `students` as the index, and `['Day3', 'Day1', 'Day2', 'Day5', 'Day4']` as the columns.

# %%
myColumns = ['Day3', 'Day1', 'Day2', 'Day5', 'Day4']
frame = pd.DataFrame(data, columns = myColumns, index = students )
frame
# Out:
#    Day3  Day1  Day2  Day5  Day4
# C   265   125   996   527   320
# H   369   123   156   985   733
# A   496   925   881     8    73
# D   256   490    40   502   420
# E   371   528   356   239   395
# J    54   344   363   122   574
# G   545   200   868   974   689
# I   691    54    77   453    13
# B   755   409   382   653   860
# F   342   798   670    89   652

# %% [markdown]
# ## Ordering
# As you might have noticed that the order of the row indices and columns are a bit mixed up. You are expected to order both in an ascending order.

# %% [markdown]
# #### TASK 2 [+2].
# Sort the dataframe based on row index.

# %%
frame = frame.sort_index(axis=0)
frame
# Out:
#    Day3  Day1  Day2  Day5  Day4
# A   496   925   881     8    73
# B   755   409   382   653   860
# C   265   125   996   527   320
# D   256   490    40   502   420
# E   371   528   356   239   395
# F   342   798   670    89   652
# G   545   200   868   974   689
# H   369   123   156   985   733
# I   691    54    77   453    13
# J    54   344   363   122   574

# %% [markdown]
# #### TASK 3 [+2]
# Sort the dataframe based on column index.

# %%
frame = frame.sort_index(axis=1)
frame
# Out:
#    Day1  Day2  Day3  Day4  Day5
# A   925   881   496    73     8
# B   409   382   755   860   653
# C   125   996   265   320   527
# D   490    40   256   420   502
# E   528   356   371   395   239
# F   798   670   342   652    89
# G   200   868   545   689   974
# H   123   156   369   733   985
# I    54    77   691    13   453
# J   344   363    54   574   122

# %% [markdown]
# ## Slicing
# In the following four tasks, you need to apply the required slicing/indexing on the dataset.

# %% [markdown]
# #### TASK 4 [+3].
#
# Select first 5 student records for the first 3 days using **`loc`**.

# %%
#Use loc for the selection
frame.loc[:'E', ['Day1', 'Day2', 'Day3']]
# Out:
#    Day1  Day2  Day3
# A   925   881   496
# B   409   382   755
# C   125   996   265
# D   490    40   256
# E   528   356   371

# %% [markdown]
# #### TASK 5 [+3].
#
# Select the first 2 student records for the last 2 days using **`iloc`**

# %%
#Use iloc for the selection
frame.iloc[:2, 3:]
# Out:
#    Day4  Day5
# A    73     8
# B   860   653

# %% [markdown]
# #### TASK 5 [+4].
#
# Select the Day 1 and Day 4 data for Student A and D. You can use either `iloc` or `loc`.

# %%
frame.iloc[[0,3], [0, 3]]
# Out:
#    Day1  Day4
# A   925    73
# D   490   420

# %% [markdown]
# ## Boolean Selection
#
# For the tasks in this section you MUST use boolean arrays.

# %% [markdown]
# #### TASK 6 [+5].
# Filter the dataframe to include only the students who have more than 400 visits on Day 1.

# %%
frame[frame['Day1']>400]
# Out:
#    Day1  Day2  Day3  Day4  Day5
# A   925   881   496    73     8
# B   409   382   755   860   653
# D   490    40   256   420   502
# E   528   356   371   395   239
# F   798   670   342   652    89

# %% [markdown]
# #### TASK 6 [+7].
# Filter the dataframe to include only the students who have more visits on the first day than the last day.

# %%
frame[frame['Day1']> frame['Day5']]
# Out:
#    Day1  Day2  Day3  Day4  Day5
# A   925   881   496    73     8
# E   528   356   371   395   239
# F   798   670   342   652    89
# J   344   363    54   574   122

# %% [markdown]
# #### TASK 7 [+12].
# Filter the dataframe to include students who have less than 100 visits on any day.
#
# [HINT: You can achieve this by creating a boolean data frame and then by using `sum` and `loc` functions.]
#
# You should not use anything beyond what is covered in the lecture notes.

# %%
frame__1 = frame <100
occc = frame__1[frame__1 == True].sum(axis=1)
frame__2 = pd.DataFrame(occc)
frame__2.columns =['Occurences']
frame__3 = frame__2['Occurences'] >0
frame__3 = pd.DataFrame(frame__3)
frame__3.columns =['Boolean']
indexess = frame__3.index[frame__3['Boolean'] == True].tolist()
frame.loc[indexess]
# Out:
#    Day1  Day2  Day3  Day4  Day5
# A   925   881   496    73     8
# D   490    40   256   420   502
# F   798   670   342   652    89
# I    54    77   691    13   453
# J   344   363    54   574   122

# %% [markdown]
# #### TASK 8 [+16].
# Compute the overall average considering the whole data (the result should be `444.2`).
#
# Then, filter the data to keep only the students who have visits more than the overall average for 3 days or more.

# %%
a= frame.mean(axis=1)
a= a.mean(axis=0)
a
# Out:
# 444.2

# %%
frame_1 = frame > 444.2
occ = frame_1[frame_1 == True].sum(axis=1)
frame_2 = pd.DataFrame(occ)
frame_2.columns =['Occurences']
frame_3 = frame_2['Occurences'] >=3
frame_3 = pd.DataFrame(frame_3)
frame_3.columns =['Boolean']
indexes = frame_3.index[frame_3['Boolean'] == True].tolist()
frame.loc[indexes]
# Out:
#    Day1  Day2  Day3  Day4  Day5
# A   925   881   496    73     8
# B   409   382   755   860   653
# F   798   670   342   652    89
# G   200   868   545   689   974

# %% [markdown]
# ## Calculating Basic Stats

# %% [markdown]
# #### TASK 9 [+5].
# Compute the average per student across all days. Here you must use the *`mean`* function. Be careful with the axis value.

# %%
frame.mean(axis=1)
# Out:
# A    476.6
# B    611.8
# C    446.6
# D    341.6
# E    377.8
# F    510.2
# G    655.2
# H    473.2
# I    257.6
# J    291.4
# dtype: float64

# %% [markdown]
# #### TASK 10 [+12].
# Return the name of the student (which is a letter) who have the lowest average page views.
#
# [HINT: You can use mean to compute the averages and order the result in descending order. Then, you can read the first index value.]
#
# DO NOT use any numpy functions for this task.

# %%
arr = frame.mean(axis=1)
arr = arr.sort_values(ascending=False)
a = arr.index
a[0]
# Out:
# 'G'

# %% [markdown]
# #### TASK 11 [+10].
# Find the number of days student A visited more pages than student D.

# %%
frame2 = frame.loc['A'] > frame.loc['D']
frame3 = pd.DataFrame(frame2)
frame3.columns =[ 'Boolean']
frame3['Boolean'].value_counts()[True]
# Out:
# 3

# %% [markdown]
# #### TASK 12 [+15].
#
# Return the list of students whose total visits until the 4th day (that is 1st, 2nd and 3rd days) is less than their visits on the 4th day.
#
# You **must** use numpy's `cumsum` function in this task.

# %%
newframe = np.cumsum (frame, axis = 1)
newframe1 =  newframe['Day3'] > frame['Day4']
newframe2 = newframe1.sort_values(ascending=True)
newframe3 = newframe2.index
newframe3[0]
# Out:
# 'H'
